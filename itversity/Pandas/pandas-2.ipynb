# %%
import pandas as pd

# %% [markdown]
# Read file as Raw data from github
# Filelocation : https://github.com/KeithGalli/complete-pandas-tutorial/blob/master/warmup-data/coffee.csv

# %%
coffee=pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv")

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %% [markdown]
# Read CSV File

# %%
results1=pd.read_csv("C:\\Users\\navaras2012\\Learn\\Data\\results.csv")
results1.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %% [markdown]
# Read parquet File

# %%
results2=pd.read_parquet("C:\\Users\\navaras2012\\Learn\\Data\\results.parquet")
results2.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %% [markdown]
# Read excel file

# %%
results3=pd.read_excel("C:\\Users\\navaras2012\\Learn\\Data\\olympics-data.xlsx",sheet_name="results")
results3.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %% [markdown]
# Read the  following Files
# - coffee.csv
# - results.parquest
# - bios.csv

# %%
coffee=pd.read_csv("C:\\Users\\navaras2012\\Learn\\Data\\coffee.csv")
results=pd.read_parquet("C:\\Users\\navaras2012\\Learn\\Data\\results.parquet")
bios=pd.read_csv("C:\\Users\\navaras2012\\Learn\\Data\\bios.csv")

# %% [markdown]
# 1.head()
# 2.tail()
# 3.sample()

# %%
coffee.sample(10)
# Out:
#           Day Coffee Type  Units Sold
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35
# 5   Wednesday       Latte          25
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 6    Thursday    Espresso          40
# 9      Friday       Latte          35
# 4   Wednesday    Espresso          35
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %% [markdown]
# 4.loc[rows,clumns] & iloc

# %%
coffee.loc[1]
# Out:
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object

# %%
coffee.loc[[0,5,8]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 5  Wednesday       Latte          25
# 8     Friday    Espresso          45

# %%
coffee.loc[:3]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
coffee.loc[5:]
# Out:
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[5:8,"Units Sold"]
# Out:
# 5    25
# 6    40
# 7    30
# 8    45
# Name: Units Sold, dtype: int64

# %%
coffee.loc[5:8,["Day","Units Sold"]]
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45

# %%
coffee.iloc[5:8,[0,2]]
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30

# %% [markdown]
# 5) index

# %%
coffee.index=coffee['Day']
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35

# %%
coffee.loc['Monday']
# Out:
#            Day Coffee Type  Units Sold
# Day
# Monday  Monday    Espresso          25
# Monday  Monday       Latte          15

# %% [markdown]
# 6)Setting values

# %%
coffee=pd.read_csv("C:\\Users\\navaras2012\\Learn\\Data\\coffee.csv")
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.loc[3,"Units Sold"]=350
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte         350
# 4  Wednesday    Espresso          35

# %% [markdown]
# 7) at/iat   - to access a single elment only

# %%
coffee.at[0,"Coffee Type"]
# Out:
# 'Espresso'

# %%
coffee.at[1,"Day"]="XXXXX"
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1      XXXXX       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte         350
# 4  Wednesday    Espresso          35

# %%
coffee.at[0:3,"Day"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 coffee.at[0:3,"Day"]
#
# File c:\Users\navaras2012\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:2575, in _AtIndexer.__getitem__(self, key)
#    2572         raise ValueError("Invalid call for scalar access (getting)!")
#    2573     return self.obj.loc[key]
# -> 2575 return super().__getitem__(key)
#
# File c:\Users\navaras2012\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:2527, in _ScalarAccessIndexer.__getitem__(self, key)
#    2524         raise ValueError("Invalid call for scalar access (getting)!")
#    2526 key = self._convert_key(key)
# -> 2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# ...

# %%
coffee.sort_values("Units Sold")
# Out:
#           Day Coffee Type  Units Sold
# 1       XXXXX       Latte          15
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 11   Saturday       Latte          35
# 9      Friday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 10   Saturday    Espresso          45
# 8      Friday    Espresso          45
# 12     Sunday    Espresso          45
# 3     Tuesday       Latte         350

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1      XXXXX       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte         350
# 4  Wednesday    Espresso          35

# %%
coffee.sort_values("Units Sold",ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte         350
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 11   Saturday       Latte          35
# 9      Friday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 1       XXXXX       Latte          15

# %%
coffee.sort_values(["Coffee Type","Units Sold"],ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte         350
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 5   Wednesday       Latte          25
# 1       XXXXX       Latte          15
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 2     Tuesday    Espresso          30
# 0      Monday    Espresso          25

# %%
coffee.sort_values(["Coffee Type","Units Sold"],ascending=[False,True])
# Out:
#           Day Coffee Type  Units Sold
# 1       XXXXX       Latte          15
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 3     Tuesday       Latte         350
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          30
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
for index,row in coffee.iterrows():
    print(index)
    print(row)
    print("\n\n")
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
#
# 1
# Day            XXXXX
# Coffee Type    Latte
# Units Sold        15
# Name: 1, dtype: object
#
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold         350
# Name: 3, dtype: object
#
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# ...
